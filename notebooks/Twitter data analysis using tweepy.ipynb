# %%
#using tweepy to access twitter data
# !pip install tweepy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
import tweepy

# %%
# using the bearer token
client = tweepy.Client(bearer_token='AAAAAAAAAAAAAAAAAAAAABpBfQEAAAAAKGYMX1%2FjMXYzhVhsivBGDqxEEj0%3DO7woV8MVqsKTQBmFu1lPtpHKlWH3dxnc4HbvogVB9S7PXbOqYr')

# %%
# Get tweets that contain the hashtag #presidentialdebate2022
# -is:retweet means I don't want retweets
# lang:en is asking for the tweets to be in english
query = '#presidentialdebate2022 -is:retweet lang:en'
tweets = client.search_recent_tweets(query=query, tweet_fields=['context_annotations', 'created_at'], max_results=100)

# %%
for tweet in tweets.data:
    print(tweet.text)
    if len(tweet.context_annotations)>0:
        print(tweet.context_annotations)
# Out:
# 𝐖𝐇𝐎 𝐈𝐒 𝐓𝐇𝐄 𝟓𝐓𝐇?
# ✅You can Win Up to 1.75x your Stake when you Predict Kenya's Next President
# ⚽Bet here https://t.co/FxrXR6lQAM
# 🔞𝗧&amp;𝗖'𝘀 𝗔𝗽𝗽𝗹𝘆
#
# #Zukabet #KenyaKwanza #Inawezekana #Presidentialdebate2022 https://t.co/OSRRyizykE
# [{'domain': {'id': '29', 'name': 'Events [Entity Service]', 'description': 'Entity Service related Events domain'}, 'entity': {'id': '1539613413449445376', 'name': '2022 Kenyan general election'}}, {'domain': {'id': '38', 'name': 'Political Race', 'description': ''}, 'entity': {'id': '1539613413449445376', 'name': '2022 Kenyan general election'}}]
# Kenya kwanza has set out funds for the SMEs this is time for small business to thrive it's great
# #PresidentialDebate2022 https://t.co/J3pJBDvLtB
# ...

# %%
type(tweets)
# Out:
# tweepy.client.Response

# %%
len(tweets)
# Out:
# 4
